# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# %%
# 1. sklearn으로 구현
from sklearn import linear_model

# raw data loading
df = pd.read_csv('./data/mnist/train.csv')

# 결측치 -> 없음
# 이상치 -> 없음
# 정규화 -> sklearn에 위임

# taining data set
x_data = df.drop('label', axis=1, inplace=False).values
t_data = df['label'].values.reshape(-1,1)

# 데이터 분리
x_train, x_test, t_train, t_test = \
train_test_split(x_data,
                 t_data,
                 test_size=0.3,
                 random_state=0)

# 모델 생성
sklearn_model = linear_model.LogisticRegression(random_state=42, max_iter=1000)

# 모델 학습
sklearn_model.fit(x_train,
                  t_train.ravel())

# 모델 평가
# y_true,
# y_pred,
print(classification_report(t_test,
                      sklearn_model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1242
#            1       0.95      0.96      0.96      1429
#            2       0.88      0.88      0.88      1276
#            3       0.87      0.87      0.87      1298
#            4       0.90      0.90      0.90      1236
#            5       0.87      0.84      0.85      1119
#            6       0.92      0.94      0.93      1243
#            7       0.92      0.90      0.91      1334
#            8       0.85      0.85      0.85      1204
#            9       0.85      0.87      0.86      1219
#
#     accuracy                           0.90     12600
#    macro avg       0.89      0.89      0.89     12600
# weighted avg       0.90      0.90      0.90     12600
# C:\Users\Joy\anaconda3\envs\data_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# 2. tensorflow로 구현
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam

# raw data loading
df = pd.read_csv('./data/mnist/train.csv')

# 독립변수와 종속변수 분리
x_data = df.drop('label', axis=1, inplace=False).values
t_data = df['label'].values.reshape(-1,1)

# 정규화
scaler = MinMaxScaler()
scaler.fit(x_data)
x_data_norm = scaler.transform(x_data)

# 데이터 분리
x_train_norm, x_test_norm, t_train, t_test = \
train_test_split(x_data_norm,
                 t_data,
                 test_size=0.3,
                 random_state=0)

# 모델 생성
keras_model = Sequential()

# layer 추가
keras_model.add(Flatten(input_shape=(784,)))
keras_model.add(Dense(10, activation='softmax'))

# model 설정
keras_model.compile(optimizer=Adam(learning_rate=1e-2),
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

# model 학습
keras_model_result = keras_model.fit(x_train_norm,
                                     t_train,
                                     epochs=100,
                                     batch_size=100,
                                     verbose=1,
                                     validation_split=0.2)
# Out:
# Epoch 1/100
# 236/236 [==============================] - 1s 4ms/step - loss: 0.4187 - accuracy: 0.8774 - val_loss: 0.3283 - val_accuracy: 0.9075
# Epoch 2/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.2972 - accuracy: 0.9153 - val_loss: 0.3191 - val_accuracy: 0.9117
# Epoch 3/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.9202 - val_loss: 0.3085 - val_accuracy: 0.9158
# Epoch 4/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.9233 - val_loss: 0.3271 - val_accuracy: 0.9068
# Epoch 5/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2556 - accuracy: 0.9255 - val_loss: 0.3317 - val_accuracy: 0.9097
# Epoch 6/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.9284 - val_loss: 0.3246 - val_accuracy: 0.9100
# Epoch 7/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.9277 - val_loss: 0.3221 - val_accuracy: 0.9151
# Epoch 8/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.2396 - accuracy: 0.9298 - val_loss: 0.3341 - val_accuracy: 0.9112
# Epoch 9/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9300 - val_loss: 0.3449 - val_accuracy: 0.9104
# Epoch 10/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9331 - val_loss: 0.3285 - val_accuracy: 0.9129
# Epoch 11/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2266 - accuracy: 0.9327 - val_loss: 0.3433 - val_accuracy: 0.9095
# Epoch 12/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.9366 - val_loss: 0.3462 - val_accuracy: 0.9100
# Epoch 13/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9348 - val_loss: 0.3538 - val_accuracy: 0.9107
# Epoch 14/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.2166 - accuracy: 0.9361 - val_loss: 0.3406 - val_accuracy: 0.9128
# Epoch 15/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.2188 - accuracy: 0.9349 - val_loss: 0.3703 - val_accuracy: 0.9037
# Epoch 16/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2149 - accuracy: 0.9366 - val_loss: 0.3517 - val_accuracy: 0.9114
# Epoch 17/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2108 - accuracy: 0.9382 - val_loss: 0.3685 - val_accuracy: 0.9053
# Epoch 18/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2113 - accuracy: 0.9369 - val_loss: 0.3706 - val_accuracy: 0.9083
# Epoch 19/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2119 - accuracy: 0.9378 - val_loss: 0.3711 - val_accuracy: 0.9043
# Epoch 20/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.9385 - val_loss: 0.3988 - val_accuracy: 0.8963
# Epoch 21/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9394 - val_loss: 0.3563 - val_accuracy: 0.9131
# Epoch 22/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9374 - val_loss: 0.3737 - val_accuracy: 0.9070
# Epoch 23/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 0.9393 - val_loss: 0.3772 - val_accuracy: 0.9044
# Epoch 24/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.2029 - accuracy: 0.9395 - val_loss: 0.3996 - val_accuracy: 0.8985
# Epoch 25/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.2003 - accuracy: 0.9392 - val_loss: 0.3741 - val_accuracy: 0.9070
# Epoch 26/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1971 - accuracy: 0.9426 - val_loss: 0.3748 - val_accuracy: 0.9087
# Epoch 27/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1974 - accuracy: 0.9408 - val_loss: 0.3796 - val_accuracy: 0.9071
# Epoch 28/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1934 - accuracy: 0.9439 - val_loss: 0.3970 - val_accuracy: 0.9027
# Epoch 29/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9409 - val_loss: 0.4041 - val_accuracy: 0.9020
# Epoch 30/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.9408 - val_loss: 0.4103 - val_accuracy: 0.9010
# Epoch 31/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9417 - val_loss: 0.3996 - val_accuracy: 0.9024
# Epoch 32/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9410 - val_loss: 0.4214 - val_accuracy: 0.8985
# Epoch 33/100
# 236/236 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9429 - val_loss: 0.4077 - val_accuracy: 0.9044
# Epoch 34/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1903 - accuracy: 0.9420 - val_loss: 0.4177 - val_accuracy: 0.8988
# Epoch 35/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1915 - accuracy: 0.9424 - val_loss: 0.4020 - val_accuracy: 0.9031
# Epoch 36/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1878 - accuracy: 0.9437 - val_loss: 0.4093 - val_accuracy: 0.9043
# Epoch 37/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1859 - accuracy: 0.9422 - val_loss: 0.4214 - val_accuracy: 0.8990
# Epoch 38/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1881 - accuracy: 0.9427 - val_loss: 0.4114 - val_accuracy: 0.9024
# Epoch 39/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1856 - accuracy: 0.9455 - val_loss: 0.4135 - val_accuracy: 0.9020
# Epoch 40/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1836 - accuracy: 0.9465 - val_loss: 0.4159 - val_accuracy: 0.9036
# Epoch 41/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1880 - accuracy: 0.9436 - val_loss: 0.4359 - val_accuracy: 0.9002
# Epoch 42/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.9458 - val_loss: 0.4245 - val_accuracy: 0.9026
# Epoch 43/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.9467 - val_loss: 0.4243 - val_accuracy: 0.9003
# Epoch 44/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1824 - accuracy: 0.9446 - val_loss: 0.4315 - val_accuracy: 0.9027
# Epoch 45/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1789 - accuracy: 0.9472 - val_loss: 0.4289 - val_accuracy: 0.9012
# Epoch 46/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9457 - val_loss: 0.4297 - val_accuracy: 0.9010
# Epoch 47/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1843 - accuracy: 0.9430 - val_loss: 0.4351 - val_accuracy: 0.9046
# Epoch 48/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1765 - accuracy: 0.9466 - val_loss: 0.4362 - val_accuracy: 0.9000
# Epoch 49/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1768 - accuracy: 0.9472 - val_loss: 0.4540 - val_accuracy: 0.8964
# Epoch 50/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1769 - accuracy: 0.9472 - val_loss: 0.4495 - val_accuracy: 0.8978
# Epoch 51/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1829 - accuracy: 0.9441 - val_loss: 0.4609 - val_accuracy: 0.8978
# Epoch 52/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1780 - accuracy: 0.9455 - val_loss: 0.4530 - val_accuracy: 0.8986
# Epoch 53/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1783 - accuracy: 0.9457 - val_loss: 0.4501 - val_accuracy: 0.8991
# Epoch 54/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1750 - accuracy: 0.9475 - val_loss: 0.4700 - val_accuracy: 0.8971
# Epoch 55/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1771 - accuracy: 0.9469 - val_loss: 0.4616 - val_accuracy: 0.8969
# Epoch 56/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1746 - accuracy: 0.9485 - val_loss: 0.4598 - val_accuracy: 0.8973
# Epoch 57/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1750 - accuracy: 0.9480 - val_loss: 0.4648 - val_accuracy: 0.8998
# Epoch 58/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1758 - accuracy: 0.9462 - val_loss: 0.4702 - val_accuracy: 0.8978
# Epoch 59/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1755 - accuracy: 0.9460 - val_loss: 0.4754 - val_accuracy: 0.8980
# Epoch 60/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1780 - accuracy: 0.9460 - val_loss: 0.4573 - val_accuracy: 0.9017
# Epoch 61/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1747 - accuracy: 0.9463 - val_loss: 0.4771 - val_accuracy: 0.8981
# Epoch 62/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1742 - accuracy: 0.9457 - val_loss: 0.4718 - val_accuracy: 0.8976
# Epoch 63/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1719 - accuracy: 0.9472 - val_loss: 0.4639 - val_accuracy: 0.8991
# Epoch 64/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1716 - accuracy: 0.9466 - val_loss: 0.4750 - val_accuracy: 0.8990
# Epoch 65/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1686 - accuracy: 0.9493 - val_loss: 0.4776 - val_accuracy: 0.8964
# Epoch 66/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1747 - accuracy: 0.9470 - val_loss: 0.4817 - val_accuracy: 0.8973
# Epoch 67/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1731 - accuracy: 0.9466 - val_loss: 0.4824 - val_accuracy: 0.9003
# Epoch 68/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1688 - accuracy: 0.9492 - val_loss: 0.4877 - val_accuracy: 0.8949
# Epoch 69/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1682 - accuracy: 0.9487 - val_loss: 0.4905 - val_accuracy: 0.8947
# Epoch 70/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1791 - accuracy: 0.9444 - val_loss: 0.4889 - val_accuracy: 0.8973
# Epoch 71/100
# 236/236 [==============================] - 1s 2ms/step - loss: 0.1708 - accuracy: 0.9476 - val_loss: 0.4899 - val_accuracy: 0.8971
# Epoch 72/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1689 - accuracy: 0.9494 - val_loss: 0.4797 - val_accuracy: 0.9009
# Epoch 73/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1684 - accuracy: 0.9483 - val_loss: 0.4884 - val_accuracy: 0.8961
# Epoch 74/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1673 - accuracy: 0.9479 - val_loss: 0.4916 - val_accuracy: 0.8997
# Epoch 75/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1672 - accuracy: 0.9508 - val_loss: 0.4940 - val_accuracy: 0.8997
# Epoch 76/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1694 - accuracy: 0.9469 - val_loss: 0.5057 - val_accuracy: 0.8949
# Epoch 77/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1677 - accuracy: 0.9498 - val_loss: 0.5128 - val_accuracy: 0.8935
# Epoch 78/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1685 - accuracy: 0.9477 - val_loss: 0.4983 - val_accuracy: 0.8976
# Epoch 79/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1700 - accuracy: 0.9475 - val_loss: 0.4936 - val_accuracy: 0.8976
# Epoch 80/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1673 - accuracy: 0.9486 - val_loss: 0.5033 - val_accuracy: 0.8971
# Epoch 81/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1652 - accuracy: 0.9509 - val_loss: 0.5028 - val_accuracy: 0.8969
# Epoch 82/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1682 - accuracy: 0.9473 - val_loss: 0.5107 - val_accuracy: 0.8985
# Epoch 83/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1632 - accuracy: 0.9508 - val_loss: 0.5217 - val_accuracy: 0.8932
# Epoch 84/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1666 - accuracy: 0.9494 - val_loss: 0.5141 - val_accuracy: 0.8947
# Epoch 85/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1604 - accuracy: 0.9521 - val_loss: 0.5132 - val_accuracy: 0.8954
# Epoch 86/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1674 - accuracy: 0.9483 - val_loss: 0.5240 - val_accuracy: 0.8951
# Epoch 87/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1676 - accuracy: 0.9486 - val_loss: 0.5162 - val_accuracy: 0.8961
# Epoch 88/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1650 - accuracy: 0.9511 - val_loss: 0.5263 - val_accuracy: 0.8935
# Epoch 89/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1630 - accuracy: 0.9497 - val_loss: 0.5259 - val_accuracy: 0.8923
# Epoch 90/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1602 - accuracy: 0.9520 - val_loss: 0.5345 - val_accuracy: 0.8939
# Epoch 91/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1624 - accuracy: 0.9502 - val_loss: 0.5436 - val_accuracy: 0.8900
# Epoch 92/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1624 - accuracy: 0.9500 - val_loss: 0.5194 - val_accuracy: 0.8969
# Epoch 93/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1616 - accuracy: 0.9496 - val_loss: 0.5204 - val_accuracy: 0.8954
# Epoch 94/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1647 - accuracy: 0.9497 - val_loss: 0.5238 - val_accuracy: 0.8980
# Epoch 95/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1600 - accuracy: 0.9517 - val_loss: 0.5345 - val_accuracy: 0.8954
# Epoch 96/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1593 - accuracy: 0.9506 - val_loss: 0.5419 - val_accuracy: 0.8923
# Epoch 97/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1607 - accuracy: 0.9511 - val_loss: 0.5573 - val_accuracy: 0.8862
# Epoch 98/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1634 - accuracy: 0.9511 - val_loss: 0.5277 - val_accuracy: 0.8981
# Epoch 99/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1594 - accuracy: 0.9518 - val_loss: 0.5456 - val_accuracy: 0.8956
# Epoch 100/100
# 236/236 [==============================] - 1s 3ms/step - loss: 0.1605 - accuracy: 0.9502 - val_loss: 0.5568 - val_accuracy: 0.8888

# %%
# 모델 평가
keras_model.evaluate(x_test_norm, t_test)
# Out:
# 394/394 [==============================] - 0s 950us/step - loss: 0.5405 - accuracy: 0.8956
# [0.5405497550964355, 0.8956349492073059]

# %%
import tensorflow as tf

print(classification_report(t_test,
                      tf.argmax(keras_model.predict(x_test_norm), axis=1).numpy()))
# Out:
# 394/394 [==============================] - 0s 793us/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      1242
#            1       0.94      0.96      0.95      1429
#            2       0.90      0.86      0.88      1276
#            3       0.90      0.84      0.87      1298
#            4       0.95      0.84      0.90      1236
#            5       0.87      0.83      0.85      1119
#            6       0.91      0.94      0.93      1243
#            7       0.90      0.92      0.91      1334
#            8       0.78      0.91      0.84      1204
#            9       0.85      0.88      0.87      1219
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.89      0.89     12600
# weighted avg       0.90      0.90      0.90     12600

# %%
# test 데이터를 이용해서 예측하고 결과를 csv 파일로 만들어 kaggle에 제출
ml_df = pd.read_csv('./data/mnist/sample_submission.csv')
ml_df
# Out:
#        ImageId  Label
# 0            1      0
# 1            2      0
# 2            3      0
# 3            4      0
# 4            5      0
# ...        ...    ...
# 27995    27996      0
# 27996    27997      0
# 27997    27998      0
# 27998    27999      0
# 27999    28000      0
#
# [28000 rows x 2 columns]

# %%
test_df = pd.read_csv('./data/mnist/test.csv')
x_data = test_df.values
scaler = MinMaxScaler()
scaler.fit(x_data)
x_data_norm = scaler.transform(x_data)
result = tf.argmax(keras_model.predict(x_data_norm), axis=1).numpy()
result
# Out:
# 875/875 [==============================] - 1s 816us/step
# array([2, 0, 9, ..., 3, 9, 2], dtype=int64)

# %%
ml_df['Label'] = result
ml_df
# Out:
#        ImageId  Label
# 0            1      2
# 1            2      0
# 2            3      9
# 3            4      7
# 4            5      3
# ...        ...    ...
# 27995    27996      9
# 27996    27997      7
# 27997    27998      3
# 27998    27999      9
# 27999    28000      2
#
# [28000 rows x 2 columns]

# %%
ml_df.to_csv('./data/mnist/ml_result.csv', index=None)

# %%
# 비정형 데이터의 학습
# 1. layer 추가
